# %%
import cv2
import numpy as np
import os
import imutils
import numpy as np
from IPython.display import Image, display

# %%
file_path = "/Users/leodidier/Documents/GitHub/image_loader_opencv/image_arithmetic"

# %%
van_gogh = cv2.imread(os.path.join("/Users/leodidier/Documents/GitHub/image_loader_opencv/Van_Gogh-Starry_Night.jpg"))

# %%
for i in range(2):
    file_name = f"starry_night_{i}.jpg"
    full_path = os.path.join(file_path, file_name)

    cv2.imwrite(full_path, van_gogh)
    display(Image(full_path))

# %%
added_pic = cv2.imread(os.path.join(file_path, "starry_night_0.jpg"))
substracted_pic = cv2.imread(os.path.join(file_path, "starry_night_1.jpg"))

# %%
added = cv2.add(np.uint8([200]), np.uint8([100]))
subtracted = cv2.subtract(np.uint8([50]), np.uint8([100]))

# %%
print(f"Added: {added}")
print(f"Subtracted: {subtracted}")
# Out:
# Added: [[300.]
#  [  0.]
#  [  0.]
#  [  0.]]
# Subtracted: [[-50.]
#  [  0.]
#  [  0.]
#  [  0.]]

# %%
print(f"Added: {type(added)}, Subtracted: {type(subtracted)}")
# Out:
# Added: <class 'numpy.ndarray'>, Subtracted: <class 'numpy.ndarray'>
